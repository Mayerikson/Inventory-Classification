# %% [markdown]
# # 📑 Sumário
#
# 1. [Análise da MYK Supply](#1-análise-da-myk-supply)
#    1.1 [Cenário: Dominando a Inteligência de Estoque com Dados](#11-cenário-dominando-a-inteligência-de-estoque-com-dados)
#    1.2 [Objeto do Projeto](#12-objeto-do-projeto)
#    1.3 [Premissas do Projeto](#13-premissas-do-projeto)
#    1.4 [Análise SWOT](#14-análise-swot)
#
# 2. [Entendimento dos Dados](#2-entendimento-dos-dados)
#    2.1 [Dicionário de Variáveis](#21-este-conjunto-de-dados-contém-os-seguintes-recursos)
#
# 3. [Preparação dos Dados](#3-preparação-dos-dados)
#    3.1 [Análise Exploratória Inicial](#31-análise-exploratória-inicial)
#
# 4. [Respondendo às Perguntas de Negócio](#4-respondendo-as-perguntas-de-negócio)
#
# 5. [Resumo Executivo das Perguntas de Negócio](#5-resumo-executivo-das-perguntas-de-negócio)
#
# 6. [Plano de Ação – 5W2H](#6-plano-de-ação--5w2h)

# %% [markdown]
# # 1 Análise da MYK Supply

# %% [markdown]
# ## 1.1 Cenário: Dominando a Inteligência de Estoque com Dados
#
# Nos últimos trimestres, a MYK Supply, empresa referência em distribuição de produtos para o setor de tecnologia e consumo, vem enfrentando desafios operacionais críticos relacionados à gestão de estoque. Em um mesmo armazém, itens essenciais sofrem com ruptura de estoque, enquanto outros, com baixa rotatividade, ocupam espaço valioso e geram custos ocultos.
#
# A área financeira e o time de logística pressionam por mais previsibilidade e eficiência, apontando para a necessidade de decisões estratégicas baseadas em dados.
#
# Diante desse cenário, a liderança executiva foi direta:
#
# *“Precisamos saber quais produtos merecem atenção total e quais estão drenando recursos. A gestão de estoque precisa ser guiada por dados e priorização inteligente.”*
#
# A partir dessa demanda, o time de analytics iniciou um projeto de inteligência operacional, com um objetivo claro: **transformar dados históricos de consumo em ações que reduzam custos e aumentem o ROI logístico.**

# %% [markdown]
# ## 1.2 Objeto do Projeto
#
# Otimizar a gestão de estoques da MYK Supply por meio da classificação ABC-XYZ, visando priorizar itens de maior impacto financeiro e operacional, reduzir capital imobilizado e ampliar a previsibilidade nas decisões de compra e reposição.
#
# Para isso, o time de dados buscará responder as seguintes perguntas:
#
# 1)Quais itens representam maior valor financeiro e devem receber atenção máxima (Classe A)?
#
# 2)Quais itens têm consumo mais imprevisível e exigem buffers ou estratégias diferenciadas (Classe Z)?
#
# 3)Quais combinações ABC-XYZ orientam políticas específicas de reabastecimento?
#
# 4)Qual o potencial de economia ao redirecionar recursos para os grupos mais estratégicos (ex: AX)?
#
# 5)Quais recomendações práticas podem ser entregues para as áreas de compras, logística e financeiro com base nessa priorização?

# %% [markdown]
# ## 1.3 Premissas do Projeto
#
# Este estudo tem como foco principal a análise da performance e previsibilidade dos itens em estoque, reconhecendo que a alocação inteligente de recursos logísticos é um vetor direto de ROI.
#
# Embora o retorno financeiro ainda não tenha sido mensurado de forma direta nesta fase, os padrões identificados aqui,como o foco em produtos AX e a possível descontinuação de itens CZ e servirão como base para simulações financeiras futuras e acompanhamento de KPIs de redução de custo e giro de estoque.
#
# A literatura de Supply Chain e experiências anteriores mostram que empresas que priorizam itens críticos (alto valor e alta previsibilidade) conseguem:
#
# **Reduzir rupturas**,
#
# **Diminuir capital parado**,
#
# **E melhorar margens operacionais**.
#
# Assim, este projeto prepara o terreno para uma segunda etapa mais voltada à mensuração do ROI e à automação de políticas de abastecimento.
#
#
# **O que é classificação ABC-XYZ?**
#
# É uma técnica de gestão de estoques que combina dois critérios: o valor financeiro dos itens (ABC) e a previsibilidade de consumo (XYZ). A análise ABC identifica quais produtos são mais valiosos para o negócio (Classe A = alto impacto financeiro; C = baixo), enquanto a XYZ avalia a regularidade da demanda (X = consumo estável; Z = imprevisível). Ao cruzar essas duas dimensões, cria-se uma matriz com 9 categorias (como AX, BY, CZ), permitindo priorizar recursos, definir estratégias de reabastecimento sob medida e melhorar o ROI logístico.

# %% [markdown]
# ## 1.4 Análise SWOT
#
#
# **Forças (Strengths)**
#
# Liderança em distribuição no setor de tecnologia e consumo: A MYK Supply é uma referência no mercado, o que fortalece sua posição competitiva e credibilidade para implementar mudanças estratégicas.
#
#
#
# Demanda clara da liderança executiva: O apoio explícito da alta gestão para decisões baseadas em dados garante alinhamento organizacional e facilita a adoção do projeto de inteligência operacional.
#
#
#
# Capacidade analítica estabelecida: A existência de um time de analytics dedicado ao projeto demonstra competência interna para transformar dados históricos em insights acionáveis.
#
#
#
# Foco na classificação ABC-XYZ: A metodologia escolhida é robusta e amplamente validada na literatura de Supply Chain, permitindo priorização precisa de itens com base em valor financeiro e previsibilidade de consumo.
#
#
#
# Potencial de redução de custos: A identificação de itens de baixa rotatividade (ex.: CZ) e o foco em produtos estratégicos (ex.: AX) abrem oportunidades claras para diminuir capital imobilizado e custos operacionais.
#
#
# **Fraquezas (Weaknesses)**
#
# Desafios operacionais críticos: As rupturas de estoque de itens essenciais e o excesso de produtos de baixa rotatividade indicam falhas na gestão atual, que podem impactar a confiança dos clientes e a eficiência logística.
#
#
#
# Falta de mensuração financeira inicial: A ausência de cálculos diretos de ROI na fase atual do projeto pode dificultar a justificativa de investimentos em curto prazo perante a área financeira.
#
#
#
# Dependência de dados históricos: A qualidade e a completude dos dados históricos de consumo são cruciais para o sucesso da análise ABC-XYZ, mas não há menção sobre a integridade desses dados.
#
#
#
# Ausência de automação inicial: O projeto ainda não contempla a automação imediata de políticas de reabastecimento, o que pode limitar a agilidade na implementação de mudanças.
#
#
#
# Pressão interna por resultados rápidos: A expectativa das áreas financeira e logística por previsibilidade e eficiência pode gerar conflitos caso os resultados demorem a se materializar.
#
#
#
# **Oportunidades (Opportunities)**
#
# Melhoria da previsibilidade operacional: A classificação ABC-XYZ pode orientar políticas de reabastecimento mais inteligentes, reduzindo rupturas de estoque e aumentando a satisfação do cliente.
#
#
#
# Redução de capital imobilizado: A descontinuação ou redução de itens CZ e o foco em AX podem liberar recursos financeiros para investimentos em áreas estratégicas.
#
#
#
# Aumento do ROI logístico: A literatura de Supply Chain indica que empresas que otimizam estoques com base em dados conseguem melhorar margens operacionais, o que pode posicionar a MYK Supply como benchmark no setor.
#
#
#
# Base para automação futura: O projeto atual cria fundamentos sólidos para uma segunda fase com automação de processos, como sistemas ERP integrados com políticas de abastecimento baseadas em IA.
#
#
#
# Fortalecimento da colaboração interdepartamental: As recomendações práticas para compras, logística e financeiro podem alinhar objetivos e melhorar a governança interna.
#
#
# **Ameaças (Threats)**
#
# Resistência à mudança: A implementação de descontinuação de itens ou mudanças nas políticas de estoque pode enfrentar resistência de fornecedores ou equipes internas acostumadas com processos tradicionais.
#
#
#
# Volatilidade na demanda do setor: O setor de tecnologia e consumo é sujeito a mudanças rápidas nas preferências do mercado, o que pode afetar a validade das classificações ABC-XYZ no longo prazo.
#
#
#
# Concorrência intensificada: A demora em otimizar a gestão de estoque pode permitir que concorrentes com maior eficiência capturem participação de mercado.
#
#
#
# Risco de falhas na execução: Problemas na comunicação entre o time de analytics e as áreas operacionais podem levar a inconsistências na aplicação das recomendações.
#
#
#
# Custos de implementação futura: A transição para uma gestão automatizada ou a integração com novas tecnologias pode exigir investimentos significativos, o que pode ser um obstáculo caso os resultados iniciais não convençam stakeholders.

# %% [markdown]
# # 2. Entendimento dos Dados

# %% [markdown]
# ## 2.1 Este conjunto de dados contém os seguintes recursos:
#
# ![image.png](attachment:32032196-0693-4c1f-b856-83b94dd2e5a2.png)

# %%
# Importação das bibliotecas necessárias

import pandas as pd
import warnings


arquivo = "abc_xyz_dataset.csv"

# Suprimir todos os avisos

warnings.filterwarnings ("ignore")
# : Importar o dataset 
df = pd.read_csv(arquivo)

# 1. Printar a contagem do número de linhas e colunas
print("➡️ Número de linhas e colunas:", df.shape)

# 2. Printar a contagem do número de valores missing por variável
print("\n➡️ Valores faltantes por variável:")
print(df.isna().sum())

# 3. Printar a contagem de linhas duplicadas
duplicadas = df.duplicated().sum()
print(f"\n➡️ Número de linhas duplicadas: {duplicadas}")

# 4. Mostrar os tipos de dados usando o comando dtypes
print("\n➡️ Tipos de dados das variáveis:")
print(df.dtypes)

# 5. Printar uma amostra aleatória de 30 linhas com o comando .sample()
print("\n➡️ Amostra aleatória de 30 linhas:")
print(df.sample(30))

# 6. Mostrar as primeiras 5 linhas com .head()
print("\n➡️ Primeiras 5 linhas do dataset:")
print(df.head())
# Out:
# ➡️ Número de linhas e colunas: (1000, 18)
#
# ➡️ Valores faltantes por variável:
# Item_ID               0
# Item_Name             0
# Category              0
# Jan_Demand            0
# Feb_Demand            0
# Mar_Demand            0
# Apr_Demand            0
# May_Demand            0
# Jun_Demand            0
# Jul_Demand            0
# Aug_Demand            0
# Sep_Demand            0
# Oct_Demand            0
# Nov_Demand            0
# Dec_Demand            0
# Total_Annual_Units    0
# Price_Per_Unit        0
# Total_Sales_Value     0
# dtype: int64
#
# ➡️ Número de linhas duplicadas: 0
#
# ➡️ Tipos de dados das variáveis:
# Item_ID               object
# Item_Name             object
# Category              object
# Jan_Demand             int64
# Feb_Demand             int64
# Mar_Demand             int64
# Apr_Demand             int64
# May_Demand             int64
# Jun_Demand             int64
# Jul_Demand             int64
# Aug_Demand             int64
# ...

# %% [markdown]
# **Interpretação:**
#
# Ao verificar os tipos de dados, percebemos que:
#
# As variáveis "Price_Per_Unit" e "Total_Sales_Value" podem ser do tipo float, especialmente se houver valores decimais.
#
# Para garantir que tudo corra bem, vamos adicionar um trecho de código para converter essas colunas para float, se necessário. Isso ajuda a evitar problemas futuros nos cálculos financeiros!

# %%
# Converter tipos específicos, se necessário
df['Price_Per_Unit'] = df['Price_Per_Unit'].astype(float)
df['Total_Sales_Value'] = df['Total_Sales_Value'].astype(float)

# Mostrar novamente os tipos de dados atualizados
print("\n➡️ Tipos de dados atualizados:")
print(df.dtypes)
# Out:
# ➡️ Tipos de dados atualizados:
# Item_ID                object
# Item_Name              object
# Category               object
# Jan_Demand              int64
# Feb_Demand              int64
# Mar_Demand              int64
# Apr_Demand              int64
# May_Demand              int64
# Jun_Demand              int64
# Jul_Demand              int64
# Aug_Demand              int64
# Sep_Demand              int64
# Oct_Demand              int64
# Nov_Demand              int64
# Dec_Demand              int64
# Total_Annual_Units      int64
# Price_Per_Unit        float64
# Total_Sales_Value     float64
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from math import ceil
import warnings
warnings.filterwarnings('ignore')

# Configurações de estilo
plt.style.use('default')
sns.set_palette("husl")
plt.rcParams['figure.dpi'] = 100
plt.rcParams['savefig.dpi'] = 300

# Definindo variáveis quantitativas e qualitativas
var_quantitativas = ['Jan_Demand', 'Feb_Demand', 'Mar_Demand', 'Apr_Demand', 'May_Demand',
                     'Jun_Demand', 'Jul_Demand', 'Aug_Demand', 'Sep_Demand', 'Oct_Demand',
                     'Nov_Demand', 'Dec_Demand', 'Total_Annual_Units', 'Price_Per_Unit',
                     'Total_Sales_Value']

var_qualitativas = ['Item_ID', 'Item_Name', 'Category']

print("📊 ANÁLISE EXPLORATÓRIA DE DADOS")
print("=" * 60)
print(f"🔢 Variáveis Quantitativas: {len(var_quantitativas)}")
print(f"🏷️ Variáveis Qualitativas: {len(var_qualitativas)}")
print(f"📋 Shape do DataFrame: {df.shape}")
print("=" * 60)

# =============================================================================
# 1. ANÁLISE DE VARIÁVEIS QUALITATIVAS
# =============================================================================
print("\n🔍 VALORES ÚNICOS NAS VARIÁVEIS QUALITATIVAS:")
print("-" * 50)

for var in var_qualitativas:
    unique_vals = df[var].unique()
    print(f"\n📋 {var}:")
    print(f"   • Valores únicos: {len(unique_vals)}")
    print(f"   • Valores nulos: {df[var].isnull().sum()}")
    
    # Mostrar apenas os primeiros 10 valores se houver muitos
    if len(unique_vals) <= 10:
        print(f"   • Valores: {list(unique_vals)}")
    else:
        print(f"   • Primeiros 10 valores: {list(unique_vals[:10])}")
        print(f"   • ... e mais {len(unique_vals) - 10} valores")

# =============================================================================
# 2. ESTATÍSTICAS DESCRITIVAS QUANTITATIVAS
# =============================================================================
print("\n\n📈 ESTATÍSTICAS DESCRITIVAS DAS VARIÁVEIS QUANTITATIVAS:")
print("-" * 50)

# Verifica se as colunas existem no DataFrame
var_quantitativas_existentes = [col for col in var_quantitativas if col in df.columns]

if var_quantitativas_existentes:
    stats_desc = df[var_quantitativas_existentes].describe().round(2)
    print(stats_desc)
    
    # Informações sobre valores nulos
    print("\n🔍 VALORES NULOS:")
    null_info = df[var_quantitativas_existentes].isnull().sum()
    if null_info.sum() > 0:
        print(null_info[null_info > 0])
    else:
        print("✅ Nenhum valor nulo encontrado!")
else:
    print("❌ Nenhuma variável quantitativa encontrada no DataFrame!")

# =============================================================================
# 3. VISUALIZAÇÕES DAS VARIÁVEIS QUANTITATIVAS
# =============================================================================
print("\n\n📊 GERANDO VISUALIZAÇÕES PARA VARIÁVEIS QUANTITATIVAS...")

if var_quantitativas_existentes:
    num_vars = len(var_quantitativas_existentes)
    num_cols = 3  # 3 colunas para melhor visualização
    num_rows = ceil(num_vars / num_cols)
    
    # HISTOGRAMAS
    fig1, axes1 = plt.subplots(nrows=num_rows, ncols=num_cols, 
                              figsize=(15, 4 * num_rows))
    fig1.suptitle('📈 Distribuição das Variáveis Quantitativas (Histogramas)', 
                  fontsize=16, fontweight='bold', y=1.05)
    
    # Garantir que axes1 seja sempre uma lista
    if num_vars == 1:
        axes1 = [axes1]
    elif num_rows == 1:
        axes1 = axes1.reshape(1, -1)
    
    axes1 = axes1.flatten()
    
    for i, col in enumerate(var_quantitativas_existentes):
        try:
            data_clean = df[col].dropna()
            
            if len(data_clean) > 0:
                sns.histplot(data=data_clean, ax=axes1[i], kde=True, 
                           alpha=0.7, color='skyblue')
                axes1[i].set_title(f'{col}', fontweight='bold', fontsize=11)
                axes1[i].grid(True, alpha=0.3)
                
                # Adicionar linha da média
                mean_val = data_clean.mean()
                axes1[i].axvline(mean_val, color='red', linestyle='--', 
                               linewidth=2, label=f'Média: {mean_val:.1f}')
                axes1[i].legend(fontsize=9)
            else:
                axes1[i].text(0.5, 0.5, f'Sem dados\n{col}', 
                            ha='center', va='center', transform=axes1[i].transAxes)
        except Exception as e:
            axes1[i].text(0.5, 0.5, f'Erro: {col}', 
                        ha='center', va='center', transform=axes1[i].transAxes)
    
    # Remover subplots vazios
    for j in range(len(var_quantitativas_existentes), len(axes1)):
        axes1[j].remove()
    
    plt.tight_layout()
    plt.show()
    
    # BOXPLOTS
    fig2, axes2 = plt.subplots(nrows=num_rows, ncols=num_cols, 
                              figsize=(15, 4 * num_rows))
    fig2.suptitle('📦 Detecção de Outliers (Boxplots)', 
                  fontsize=16, fontweight='bold', y=1.05)
    
    # Garantir que axes2 seja sempre uma lista
    if num_vars == 1:
        axes2 = [axes2]
    elif num_rows == 1:
        axes2 = axes2.reshape(1, -1)
    
    axes2 = axes2.flatten()
    
    for i, col in enumerate(var_quantitativas_existentes):
        try:
            data_clean = df[col].dropna()
            
            if len(data_clean) > 0:
                sns.boxplot(y=data_clean, ax=axes2[i], color='lightgreen')
                axes2[i].set_title(f'{col}', fontweight='bold', fontsize=11)
                axes2[i].grid(True, alpha=0.3)
                
                # Contar outliers
                Q1 = data_clean.quantile(0.25)
                Q3 = data_clean.quantile(0.75)
                IQR = Q3 - Q1
                outliers = data_clean[(data_clean < Q1 - 1.5*IQR) | 
                                    (data_clean > Q3 + 1.5*IQR)]
                
                if len(outliers) > 0:
                    axes2[i].text(0.02, 0.98, f'Outliers: {len(outliers)}', 
                                transform=axes2[i].transAxes, 
                                verticalalignment='top', fontsize=9,
                                bbox=dict(boxstyle='round', facecolor='yellow', alpha=0.7))
            else:
                axes2[i].text(0.5, 0.5, f'Sem dados\n{col}', 
                            ha='center', va='center', transform=axes2[i].transAxes)
        except Exception as e:
            axes2[i].text(0.5, 0.5, f'Erro: {col}', 
                        ha='center', va='center', transform=axes2[i].transAxes)
    
    # Remover subplots vazios
    for j in range(len(var_quantitativas_existentes), len(axes2)):
        axes2[j].remove()
    
    plt.tight_layout()
    plt.show()

# =============================================================================
# 4. VISUALIZAÇÕES DAS VARIÁVEIS QUALITATIVAS
# =============================================================================
print("\n📊 GERANDO VISUALIZAÇÕES PARA VARIÁVEIS QUALITATIVAS...")

# Verifica se as colunas existem no DataFrame
var_qualitativas_existentes = [col for col in var_qualitativas if col in df.columns]

if var_qualitativas_existentes:
    num_vars_quali = len(var_qualitativas_existentes)
    num_cols_quali = 2  # 2 colunas para variáveis qualitativas
    num_rows_quali = ceil(num_vars_quali / num_cols_quali)
    
    fig3, axes3 = plt.subplots(nrows=num_rows_quali, ncols=num_cols_quali, 
                              figsize=(14, 5 * num_rows_quali))
    fig3.suptitle('📊 Distribuição das Variáveis Qualitativas', 

                  fontsize=16, fontweight='bold', y=1.08)
    
    # Garantir que axes3 seja sempre uma lista
    if num_vars_quali == 1:
        axes3 = [axes3]
    elif num_rows_quali == 1:
        axes3 = axes3.reshape(1, -1)
    
    axes3 = axes3.flatten()
    
    for i, col in enumerate(var_qualitativas_existentes):
        try:
            # Contar valores únicos
            value_counts = df[col].value_counts()
            
            if len(value_counts) > 0:
                # Limitar a 15 categorias mais frequentes
                if len(value_counts) > 15:
                    value_counts = value_counts.head(15)
                    title_suffix = f' (Top 15 de {len(df[col].unique())})'
                else:
                    title_suffix = ''
                
                # Criar gráfico de barras
                bars = axes3[i].bar(range(len(value_counts)), value_counts.values, 
                                  color='steelblue', alpha=0.8)
                
                axes3[i].set_title(f'{col}{title_suffix}', fontweight='bold', fontsize=12)
                axes3[i].set_xlabel(col, fontsize=10)
                axes3[i].set_ylabel('Frequência', fontsize=10)
                axes3[i].set_xticks(range(len(value_counts)))
                axes3[i].set_xticklabels(value_counts.index, rotation=45, ha='right')
                axes3[i].grid(True, alpha=0.3)
                
                # Adicionar valores nas barras
                for bar, value in zip(bars, value_counts.values):
                    height = bar.get_height()
                    axes3[i].text(bar.get_x() + bar.get_width()/2., height,
                                f'{value}', ha='center', va='bottom', fontsize=9)
            else:
                axes3[i].text(0.5, 0.5, f'Sem dados\n{col}', 
                            ha='center', va='center', transform=axes3[i].transAxes)
        except Exception as e:
            axes3[i].text(0.5, 0.5, f'Erro: {col}', 
                        ha='center', va='center', transform=axes3[i].transAxes)
    
    # Remover subplots vazios
    for j in range(len(var_qualitativas_existentes), len(axes3)):
        axes3[j].remove()
    
    plt.tight_layout()
    plt.show()

else:
    print("❌ Nenhuma variável qualitativa encontrada no DataFrame!")

print("\n✅ ANÁLISE EXPLORATÓRIA CONCLUÍDA!")
print("=" * 60)
# Out:
# 📊 ANÁLISE EXPLORATÓRIA DE DADOS
# ...
# 🔢 Variáveis Quantitativas: 15
# 🏷️ Variáveis Qualitativas: 3
# 📋 Shape do DataFrame: (1000, 18)
# ...
#
# 🔍 VALORES ÚNICOS NAS VARIÁVEIS QUALITATIVAS:
# --------------------------------------------------
#
# 📋 Item_ID:
#    • Valores únicos: 1000
#    • Valores nulos: 0
#    • Primeiros 10 valores: ['ITM_001', 'ITM_002', 'ITM_003', 'ITM_004', 'ITM_005', 'ITM_006', 'ITM_007', 'ITM_008', 'ITM_009', 'ITM_010']
#    • ... e mais 990 valores
#
# 📋 Item_Name:
#    • Valores únicos: 1000
#    • Valores nulos: 0
#    • Primeiros 10 valores: ['Surface Near', 'Central Him', 'Win Everyone', 'Task Save', 'Hotel Teacher', 'Special Strategy', 'Memory Expert', 'About No', 'After Finally', 'Require Goal']
#    • ... e mais 990 valores
#
# 📋 Category:
#    • Valores únicos: 5
#    • Valores nulos: 0
#    • Valores: ['Grocery', 'Apparel', 'Toys', 'Electronics', 'Home & Kitchen']
#
#
# 📈 ESTATÍSTICAS DESCRITIVAS DAS VARIÁVEIS QUANTITATIVAS:
# ...

# %% [markdown]
# **Interpretação**
#
#
# Outliers: Presentes, especialmente em Price_Per_Unit, Total_Annual_Units e Total_Sales_Value.
#
# Categorias: Não requerem padronização no momento, pois estão consistentes. Monitorar a entrada de novos dados para manter essa uniformidade.
#
#
#
# *Estatísticas Descritivas Relevantes:*
#
# Média e Desvio Padrão: As variáveis como Jan_Demand a Dec_Demand têm médias em torno de 1400-1420 unidades, com desvios padrão próximos a 1480-1490, indicando variabilidade significativa.
#
# Total_Annual_Units tem média de 16.961,90 e desvio padrão de 17.788,48, sugerindo uma distribuição assimétrica. Price_Per_Unit e Total_Sales_Value têm médias de 57,36 e 1.072.287,90, respectivamente, com desvios padrão muito altos (155,11 e 4.087.476,96), o que pode indicar outliers extremos.
#
# Máximos e Percentis: Os valores máximos são significativamente maiores que o terceiro quartil (ex.: Total_Annual_Units vai até 59.967, enquanto Q3 é 29.874,50; Total_Sales_Value atinge 59.462.000, com Q3 em 378.242,50). Isso sugere a presença de valores extremos.
#
# *Insights dos Boxplots:*
#
# Presença de Outliers: Os boxplots provavelmente mostram pontos fora dos "bigodes" (whiskers) para a maioria das variáveis, especialmente Total_Annual_Units, Price_Per_Unit e Total_Sales_Value. Por exemplo, o texto nos boxplots indica a contagem de outliers (ex.: "Outliers: X"), o que confirma a existência de valores atípicos. Isso é esperado dado o grande desvio padrão e a diferença entre os valores máximos e Q3.
#
# Impacto: Outliers em Price_Per_Unit (máximo 1000 vs. Q3 50) e Total_Sales_Value (máximo 59.462.000 vs. Q3 378.242,50) podem distorcer análises como médias e correlações. Em Total_Annual_Units, outliers podem refletir itens de alta demanda sazonal ou erros de registro.
#
#
#
# *Dados das Variáveis Qualitativas:*
#
# Item_ID: 1000 valores únicos, sem nulos. Cada valor parece ser um identificador único por item, sem necessidade de padronização, pois a unicidade é intencional.
#
# Item_Name: 1000 valores únicos, sem nulos. Cada nome é único e parece ser gerado aleatoriamente (ex.: "Surface Near", "Central Him"), sem duplicatas ou variantes óbvias como "Brasil" e "Brazil". Não há necessidade de padronização, pois a diversidade reflete itens distintos.
#
# Category: 5 valores únicos (Grocery, Apparel, Toys, Electronics, Home & Kitchen), sem nulos. As categorias estão bem definidas e não apresentam variantes óbvias (ex.: "Grocery" vs. "Groceries" ou "Electronics" vs. "Electronic").

# %%
import pandas as pd
import numpy as np

# Definindo variáveis quantitativas e qualitativas com base nos dados fornecidos
var_quantitativas = ['Jan_Demand', 'Feb_Demand', 'Mar_Demand', 'Apr_Demand', 'May_Demand',
                     'Jun_Demand', 'Jul_Demand', 'Aug_Demand', 'Sep_Demand', 'Oct_Demand',
                     'Nov_Demand', 'Dec_Demand', 'Total_Annual_Units', 'Price_Per_Unit',
                     'Total_Sales_Value']
var_qualitativas = ['Item_ID', 'Item_Name', 'Category']

# Função para detectar outliers usando IQR
def detect_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)][[column, 'Item_Name', 'Category']]
    return outliers

# 1. Identificação de Outliers nas Variáveis Quantitativas
print("📊 EXEMPLO DE OUTLIERS NAS VARIÁVEIS QUANTITATIVAS")
print("=" * 60)

for var in var_quantitativas:
    if var in df.columns:
        outliers = detect_outliers(df, var)
        if not outliers.empty:
            print(f"\n🔍 {var}:")
            print(f"   • Número de outliers: {len(outliers)}")
            print(f"   • Exemplos de outliers:")
            print(outliers.head(3))  # Mostra os primeiros 3 exemplos
        else:
            print(f"\n✅ {var}: Nenhum outlier detectado.")

# 2. Verificação de Inconsistências nas Variáveis Qualitativas
print("\n\n🔍 VERIFICAÇÃO DE INCONSISTÊNCIAS NAS VARIÁVEIS QUALITATIVAS")
print("=" * 60)

for var in var_qualitativas:
    if var in df.columns:
        # Criar uma cópia da coluna para análise
        temp_col = df[var].astype(str).str.lower().str.strip()  # Normaliza para minúsculas e remove espaços
        
        # Contar valores únicos após normalização
        unique_normalized = temp_col.unique()
        unique_original = df[var].unique()
        
        # Verificar se há duplicatas disfarçadas (mesmo valor normalizado, mas diferente no original)
        potential_inconsistencies = {}
        for val_norm in unique_normalized:
            original_vals = df[var][temp_col == val_norm].unique()
            if len(original_vals) > 1:
                potential_inconsistencies[val_norm] = original_vals.tolist()
        
        print(f"\n📋 {var}:")
        print(f"   • Valores únicos: {len(unique_original)}")
        print(f"   • Valores nulos: {df[var].isnull().sum()}")
        
        if potential_inconsistencies:
            print(f"   • Possíveis inconsistências detectadas:")
            for norm_val, orig_vals in potential_inconsistencies.items():
                print(f"     - Normalizado: '{norm_val}' -> Originais: {orig_vals}")
        else:
            print(f"   ✅ Nenhuma inconsistência óbvia detectada (ex.: maiúsculas/minúsculas ou espaços).")

# Exibir amostra de dados com possíveis inconsistências (se existirem)
if potential_inconsistencies:
    print("\n📋 AMOSTRA DE DADOS COM INCONSISTÊNCIAS:")
    for var in var_qualitativas:
        temp_col = df[var].astype(str).str.lower().str.strip()
        for norm_val, orig_vals in potential_inconsistencies.items():
            if norm_val in temp_col.values:
                sample = df[df[var].isin(orig_vals)].head(3)
                print(f"\n🔍 {var} (Normalizado: '{norm_val}'):")
                print(sample[['Item_ID', var, 'Category']])
# Out:
# 📊 EXEMPLO DE OUTLIERS NAS VARIÁVEIS QUANTITATIVAS
# ...
#
# ✅ Jan_Demand: Nenhum outlier detectado.
#
# ✅ Feb_Demand: Nenhum outlier detectado.
#
# ✅ Mar_Demand: Nenhum outlier detectado.
#
# ✅ Apr_Demand: Nenhum outlier detectado.
#
# ✅ May_Demand: Nenhum outlier detectado.
#
# ✅ Jun_Demand: Nenhum outlier detectado.
#
# ✅ Jul_Demand: Nenhum outlier detectado.
#
# ✅ Aug_Demand: Nenhum outlier detectado.
#
# ✅ Sep_Demand: Nenhum outlier detectado.
#
# ✅ Oct_Demand: Nenhum outlier detectado.
#
# ✅ Nov_Demand: Nenhum outlier detectado.
#
# ✅ Dec_Demand: Nenhum outlier detectado.
#
# ✅ Total_Annual_Units: Nenhum outlier detectado.
#
# 🔍 Price_Per_Unit:
#    • Número de outliers: 59
#    • Exemplos de outliers:
#     Price_Per_Unit             Item_Name     Category
# 10           500.0            Water Hair      Grocery
# 21           500.0            Road Store  Electronics
# 91           500.0  Production Treatment      Apparel
#
# 🔍 Total_Sales_Value:
#    • Número de outliers: 151
# ...

# %% [markdown]
# # 3 Preparação dos dados

# %%
import pandas as pd
import numpy as np

# Definindo variáveis quantitativas e qualitativas
var_quantitativas = ['Jan_Demand', 'Feb_Demand', 'Mar_Demand', 'Apr_Demand', 'May_Demand',
                     'Jun_Demand', 'Jul_Demand', 'Aug_Demand', 'Sep_Demand', 'Oct_Demand',
                     'Nov_Demand', 'Dec_Demand', 'Total_Annual_Units', 'Price_Per_Unit',
                     'Total_Sales_Value']
var_qualitativas = ['Item_ID', 'Item_Name', 'Category']

# 1. Tratamento de Dados Faltantes
print("📊 PREPARAÇÃO DOS DADOS")
print("=" * 60)
print("🔍 1. Verificação e Tratamento de Dados Faltantes:")
missing_data = df.isnull().sum()
if missing_data.sum() > 0:
    print("⚠️ Dados faltantes detectados e tratados:")
    for col in missing_data[missing_data > 0].index:
        if col in var_quantitativas:
            df[col].fillna(df[col].mean(), inplace=True)  # Substitui por média para numéricas
        else:
            df[col].fillna(df[col].mode()[0], inplace=True)  # Substitui por moda para categóricas
    print(missing_data[missing_data > 0])
else:
    print("✅ Nenhum dado faltante detectado. Nenhum tratamento realizado.")

# 2. Tratamento de Outliers
print("\n🔍 2. Tratamento de Outliers:")
def cap_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers_count = len(df[(df[column] < lower_bound) | (df[column] > upper_bound)])
    df[column] = df[column].clip(lower_bound, upper_bound)  # Capa os valores
    return outliers_count

outlier_counts = {}
for var in var_quantitativas:
    if var in df.columns:
        count = cap_outliers(df, var)
        if count > 0:
            outlier_counts[var] = count

if outlier_counts:
    print("⚠️ Outliers tratados por capping (valores limitados ao IQR):")
    for var, count in outlier_counts.items():
        print(f"   • {var}: {count} outliers")
else:
    print("✅ Nenhum outlier significativo detectado ou tratado.")

# 3. Remoção de Linhas Duplicadas
print("\n🔍 3. Remoção de Linhas Duplicadas:")
initial_rows = len(df)
df.drop_duplicates(inplace=True)
final_rows = len(df)
if initial_rows > final_rows:
    print(f"⚠️ {initial_rows - final_rows} linhas duplicadas removidas.")
else:
    print("✅ Nenhuma linha duplicada detectada. Nenhum tratamento realizado.")

# 4. Padronização de Categorias
print("\n🔍 4. Padronização de Categorias:")
inconsistencies = {}
for var in var_qualitativas:
    if var in df.columns:
        temp_col = df[var].astype(str).str.lower().str.strip()
        unique_normalized = temp_col.unique()
        unique_original = df[var].unique()
        for val_norm in unique_normalized:
            original_vals = df[var][temp_col == val_norm].unique()
            if len(original_vals) > 1:
                inconsistencies[var] = {val_norm: original_vals.tolist()}

if inconsistencies:
    print("⚠️ Inconsistências detectadas e padronizadas:")
    for var, issues in inconsistencies.items():
        for norm_val, orig_vals in issues.items():
            df[var] = df[var].replace(orig_vals, orig_vals[0])  # Substitui por primeiro valor
            print(f"   • {var}: Normalizado '{norm_val}' -> '{orig_vals[0]}' (substituiu {orig_vals})")
else:
    print("✅ Nenhuma inconsistência de categoria detectada. Nenhum tratamento realizado.")

# 5. Criação de Variáveis Derivadas
print("\n🔍 5. Criação de Variáveis Derivadas:")
df['Average_Monthly_Demand'] = df[['Jan_Demand', 'Feb_Demand', 'Mar_Demand', 'Apr_Demand',
                                   'May_Demand', 'Jun_Demand', 'Jul_Demand', 'Aug_Demand',
                                   'Sep_Demand', 'Oct_Demand', 'Nov_Demand', 'Dec_Demand']].mean(axis=1)
df['Sales_Per_Unit'] = df['Total_Sales_Value'] / df['Total_Annual_Units']
print("✅ Criadas variáveis derivadas:")
print("   • Average_Monthly_Demand: Média mensal de demanda.")
print("   • Sales_Per_Unit: Relação entre Total_Sales_Value e Total_Annual_Units.")

# 6. Validação das Transformações
print("\n🔍 6. Validação das Transformações:")
print("\n📋 Estatísticas Descritivas Após Transformações:")
print(df[var_quantitativas + ['Average_Monthly_Demand', 'Sales_Per_Unit']].describe().round(2))

print("\n🔍 Verificação de Outliers Após Tratamento:")
for var in var_quantitativas + ['Average_Monthly_Demand', 'Sales_Per_Unit']:
    if var in df.columns:
        outliers_post = detect_outliers(df, var)
        if not outliers_post.empty:
            print(f"⚠️ {var}: {len(outliers_post)} outliers restantes após tratamento.")
        else:
            print(f"✅ {var}: Nenhum outlier detectado após tratamento.")

print("\n✅ PREPARAÇÃO DOS DADOS CONCLUÍDA!")
print("=" * 60)

# Função auxiliar para detectar outliers (usada na validação)
def detect_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] < lower_bound) | (df[column] > upper_bound)]
# Out:
# 📊 PREPARAÇÃO DOS DADOS
# ...
# 🔍 1. Verificação e Tratamento de Dados Faltantes:
# ✅ Nenhum dado faltante detectado. Nenhum tratamento realizado.
#
# 🔍 2. Tratamento de Outliers:
# ⚠️ Outliers tratados por capping (valores limitados ao IQR):
#    • Price_Per_Unit: 59 outliers
#    • Total_Sales_Value: 151 outliers
#
# 🔍 3. Remoção de Linhas Duplicadas:
# ✅ Nenhuma linha duplicada detectada. Nenhum tratamento realizado.
#
# 🔍 4. Padronização de Categorias:
# ✅ Nenhuma inconsistência de categoria detectada. Nenhum tratamento realizado.
#
# 🔍 5. Criação de Variáveis Derivadas:
# ✅ Criadas variáveis derivadas:
#    • Average_Monthly_Demand: Média mensal de demanda.
#    • Sales_Per_Unit: Relação entre Total_Sales_Value e Total_Annual_Units.
#
# 🔍 6. Validação das Transformações:
#
# 📋 Estatísticas Descritivas Após Transformações:
#        Jan_Demand  Feb_Demand  Mar_Demand  Apr_Demand  May_Demand  Jun_Demand  \
# count     1000.00     1000.00     1000.00     1000.00     1000.00     1000.00
# ...

# %% [markdown]
# **Interpretação**
#
# Avaliação dos Resultados da Preparação dos Dados
#
# 1. As transformações que fiz foram adequadas?
#
# Sim, as transformações realizadas foram adequadas com base nos dados fornecidos e nas necessidades identificadas. Vou explicar ponto a ponto:
#
# *Tratamento de Dados Faltantes*: Como não havia dados faltantes, não foi necessário realizar nenhum tratamento, o que foi confirmado. Essa decisão foi correta, pois evitar manipulações desnecessárias preserva a integridade dos dados originais.
#
# *Tratamento de Outliers*: O capping dos outliers usando o método IQR foi eficaz para Price_Per_Unit (59 outliers) e Total_Sales_Value (151 outliers). Os valores máximos foram reduzidos (ex.: Price_Per_Unit de 1000 para 122, Total_Sales_Value de 59.462.000 para 920.677,75), trazendo os dados para um intervalo mais manejável sem perder informações essenciais. No entanto, a variável derivada Sales_Per_Unit apresentou 86 outliers restantes, o que sugere que o capping pode não ter sido suficiente para essa nova métrica. Talvez valha considerar um tratamento adicional específico para ela.
#
# *Remoção de Linhas Duplicadas*: A ausência de duplicatas foi confirmada, então nenhuma ação foi necessária, o que está alinhado com os dados iniciais.
# Padronização de Categorias: Não foram detectadas inconsistências, o que é consistente com a análise anterior. Portanto, não houve necessidade de padronização, e a decisão de não alterar as categorias foi apropriada.
#
# *Criação de Variáveis Derivadas*: As novas variáveis Average_Monthly_Demand e Sales_Per_Unit adicionaram valor analítico. A média mensal de demanda fornece uma visão consolidada, e a relação vendas por unidade pode ajudar a avaliar a eficiência de preços. No entanto, os outliers em Sales_Per_Unit indicam que essa métrica pode precisar de ajustes adicionais.
#
# 2. Perdemos informação importante?
#
# Não perdemos informação importante de forma significativa, mas há alguns pontos a considerar:
#
# *Outliers*: O capping limitou os valores extremos (ex.: Price_Per_Unit e Total_Sales_Value), o que pode ter suprimido informações sobre itens de alto valor ou demanda excepcional. No entanto, como os outliers foram apenas capados (e não removidos), os dados ainda refletem a presença desses casos dentro dos limites do IQR, evitando perdas completas. A escolha de capping em vez de remoção foi prudente para preservar a maioria dos dados.
#
# *Sales_Per_Unit*: Os 86 outliers restantes sugerem que a derivação desta variável pode ter amplificado variações extremas (provavelmente devido à divisão de Total_Sales_Value por Total_Annual_Units, que já continha outliers antes do tratamento). Isso não representa uma perda, mas sim um desafio na interpretação, que pode ser abordado com ajustes adicionais.
#
# *Outras Variáveis*: As demandas mensais e Total_Annual_Units não apresentaram outliers após o tratamento, indicando que as transformações foram bem-sucedidas sem perda significativa.
#
# 3. Os dados estão prontos para análise?
#
# Os dados estão quase prontos para análise, mas com uma ressalva:
#
# *Geral*: A ausência de dados faltantes, duplicatas e inconsistências de categorias, combinada com o tratamento de outliers na maioria das variáveis, deixa o dataset em uma condição sólida para análises exploratórias ou modelagem. As estatísticas descritivas pós-tratamento mostram distribuições mais equilibradas (ex.: Price_Per_Unit max reduzido de 1000 para 122).
#
# *Exceção*: Os 86 outliers em Sales_Per_Unit indicam que essa variável derivada precisa de atenção adicional. Antes de prosseguir com análises que dependam dela (ex.: regressões ou clustering), sugiro tratar esses outliers (por exemplo, com um capping mais rigoroso ou transformação logarítmica) ou excluí-la temporariamente se não for crítica.
#
# *Próximos Passos*: Com base nisso, os dados estão prontos para análises descritivas (ex.: médias, medianas) e visuais (ex.: histogramas).
#
# 4. Que cuidados devo ter na interpretação?
#
# Ao interpretar os resultados, devo ter os seguintes cuidados:
#
# *Impacto dos Outliers Tratados*: foi usado capping, os valores máximos de Price_Per_Unit e Total_Sales_Value foram ajustados para os limites do IQR. Isso pode subestimar o impacto de itens de alto valor ou demanda em análises agregadas (ex.: receita total). Devo interpretar esses dados como representativos de um intervalo típico, mas estar ciente de que casos extremos foram suavizados.
#
# *Sales_Per_Unit*: Os outliers restantes nessa variável sugerem que alguns itens podem ter preços ou vendas anômalos. Devo investigar esses casos (ex.: cruzar com Item_Name ou Category) para entender se são erros ou características reais (ex.: produtos de luxo). Alternativamente, posso aplicar uma transformação (ex.: log) ou usar estatísticas robustas (ex.: mediana) ao analisá-la.
#
# *Variáveis Derivadas*: A Average_Monthly_Demand parece bem comportada (sem outliers), mas devo verificar se reflete padrões sazonais ao longo do ano. Para Sales_Per_Unit, devo ser cauteloso ao compará-la entre categorias, dado os outliers.
#
# *Contexto de Negócio*: Deve-se considerar o domínio dos dados (ex.: varejo) para interpretar se os limites do IQR são realistas. Por exemplo, um Price_Per_Unit de 122 ainda pode ser alto para algumas categorias como "Grocery".

# %%
# Função para criar tabelas de frequência para variáveis qualitativas
def frequency_tables_qualitative(df, var_qualitativas):
    for var in var_qualitativas:
        if var in df.columns:
            # Frequência Absoluta
            freq_abs = df[var].value_counts().sort_index()
            
            # Frequência Relativa
            freq_rel = df[var].value_counts(normalize=True).sort_index().round(4) * 100
            
            # Frequência Acumulada em Percentual
            freq_acum = (df[var].value_counts(normalize=True).sort_index().cumsum() * 100).round(2)
            
            print(f"\n📊 Tabelas de Frequência para {var}")
            print("=" * 50)
            print(f"🔢 Frequência Absoluta:\n{freq_abs}\n")
            print(f"📊 Frequência Relativa (%):\n{freq_rel}\n")
            print(f"📈 Frequência Acumulada (%):\n{freq_acum}\n")

# Função para criar faixas de valores e tabelas de frequência para variáveis quantitativas
def frequency_tables_quantitative(df, var_quantitativas):
    for var in var_quantitativas:
        if var in df.columns:
            # Calcular número de faixas (~10% dos dados por faixa)
            n_bins = int(len(df) * 0.1)  # Aproximadamente 10% por faixa
            if n_bins < 5:  # Mínimo de 5 faixas para evitar subdivisões muito grosseiras
                n_bins = 5
            
            # Criar faixas com base no mínimo e máximo, ajustando amplitude
            min_val = df[var].min()
            max_val = df[var].max()
            bin_width = (max_val - min_val) / n_bins
            bins = [min_val + i * bin_width for i in range(n_bins + 1)]
            
            # Garantir que a última faixa inclua o valor máximo
            bins[-1] = max_val + 1
            
            # Criar rótulos para as faixas
            labels = [f'{bins[i]:.1f} - {bins[i+1]:.1f}' for i in range(len(bins)-1)]
            
            # Categorizar os dados
            df[f'{var}_binned'] = pd.cut(df[var], bins=bins, labels=labels, include_lowest=True)
            
            # Frequência Absoluta
            freq_abs = df[f'{var}_binned'].value_counts().sort_index()
            
            # Frequência Relativa
            freq_rel = df[f'{var}_binned'].value_counts(normalize=True).sort_index().round(4) * 100
            
            # Frequência Acumulada em Percentual
            freq_acum = (df[f'{var}_binned'].value_counts(normalize=True).sort_index().cumsum() * 100).round(2)
            
            print(f"\n📊 Tabelas de Frequência para {var}")
            print("=" * 50)
            print(f"🔢 Frequência Absoluta:\n{freq_abs}\n")
            print(f"📊 Frequência Relativa (%):\n{freq_rel}\n")
            print(f"📈 Frequência Acumulada (%):\n{freq_acum}\n")
            
            # Remover a coluna temporária após uso
            df.drop(columns=[f'{var}_binned'], inplace=True)

# Executar as funções com as variáveis definidas anteriormente
print("📊 GERAÇÃO DE TABELAS DE FREQUÊNCIA")
print("=" * 60)

# Adicionar as novas variáveis derivadas
var_quantitativas.extend(['Average_Monthly_Demand', 'Sales_Per_Unit'])

# Gerar tabelas para variáveis qualitativas
frequency_tables_qualitative(df, var_qualitativas)

# Gerar tabelas para variáveis quantitativas
frequency_tables_quantitative(df, var_quantitativas)
# Out:
# 📊 GERAÇÃO DE TABELAS DE FREQUÊNCIA
# ...
#
# 📊 Tabelas de Frequência para Item_ID
# ...
# 🔢 Frequência Absoluta:
# Item_ID
# ITM_001    1
# ITM_002    1
# ITM_003    1
# ITM_004    1
# ITM_005    1
#           ..
# ITM_995    1
# ITM_996    1
# ITM_997    1
# ITM_998    1
# ITM_999    1
# Name: count, Length: 1000, dtype: int64
#
# 📊 Frequência Relativa (%):
# Item_ID
# ITM_001    0.1
# ITM_002    0.1
# ITM_003    0.1
# ITM_004    0.1
# ITM_005    0.1
#           ...
# ITM_995    0.1
# ITM_996    0.1
# ITM_997    0.1
# ITM_998    0.1
# ITM_999    0.1
# Name: proportion, Length: 1000, dtype: float64
#
# 📈 Frequência Acumulada (%):
# Item_ID
# ITM_001      0.1
# ITM_002      0.2
# ITM_003      0.3
# ITM_004      0.4
# ITM_005      0.5
#            ...
# ITM_995     99.6
# ITM_996     99.7
# ITM_997     99.8
# ITM_998     99.9
# ITM_999    100.0
# Name: proportion, Length: 1000, dtype: float64
#
#
# 📊 Tabelas de Frequência para Item_Name
# ...
# 🔢 Frequência Absoluta:
# Item_Name
# Able Develop       1
# ...

# %% [markdown]
# ## 3.1 Análise exploratória inicial
#
# **Objetivo do projeto:**
#
# Analisar o padrão de demanda e vendas de produtos para identificar tendências sazonais, categorias mais relevantes e distribuição de preços, visando otimizar estoques e estratégias de precificação.
#
# ---
#
# ## Variáveis Qualitativas
#
# ### 1. **Item_ID**
#
# - **Tipo:** Qualitativa (Identificador único)
# - **Tabela:**
#   | Frequência Absoluta | Frequência Relativa (%) | Frequência Acumulada (%) |
#   |---------------------|-------------------------|--------------------------|
#   | ITM_001 a ITM_999   | 0.1 (cada)              | 0.1 a 100.0 (linear)     |
#
# **Insights:**
# - Distribuição uniforme (0.1% por item), como esperado para identificadores únicos.
#
# ---
#
# ### 2. **Item_Name**
# - **Tipo:** Qualitativa (Nome do produto)
# - **Tabela:**
#   | Frequência Absoluta | Frequência Relativa (%) | Frequência Acumulada (%) |
#   |---------------------|-------------------------|--------------------------|
#   | Nomes únicos        | 0.1 (cada)              | 0.1 a 100.0 (linear)     |
#
# **Insights:**
# - Todos os nomes são únicos, sem repetições.
#
# ---
#
# ### 3. **Category**
# - **Tipo:** Qualitativa (Categoria do produto)
# - **Tabela:**
#   | Categoria       | Frequência Absoluta | Frequência Relativa (%) | Frequência Acumulada (%) |
#   |-----------------|---------------------|-------------------------|--------------------------|
#   | Grocery         | 402                 | 40.2                    | 81.1                     |
#   | Apparel         | 216                 | 21.6                    | 21.6                     |
#   | Electronics     | 193                 | 19.3                    | 40.9                     |
#   | Home & Kitchen  | 100                 | 10.0                    | 91.1                     |
#   | Toys            | 89                  | 8.9                     | 100.0                    |
#
# **Gráfico:**
# ![](grafico_bar_Category.png)
#
# **Insights:**
# - **Grocery** é a categoria dominante (40.2%), seguida por **Apparel** (21.6%) e **Electronics** (19.3%).
# - **Toys** tem a menor representação (8.9%).
#
# ---
#
# ## Variáveis Quantitativas
#
# ### 4. **Análise Temporal da Demanda Mensal (Jan_Demand a Dec_Demand)**
# - **Tipo:** Quantitativa (Distribuição de demanda por mês)
# - **Padrão Comum:**
#   - Faixas iniciais (ex.: 24.0 - 76.5 para Jan_Demand) concentram 3-7% dos dados.
#   - Faixas acima de 5000 unidades são raras (≤0.5% cada).
#
# **Gráfico (exemplo para Jan_Demand):**
# ![](grafico_linha_temporal_demanda.png)
# ![image.png](attachment:8ab6ad09-9e77-4abf-86ce-33af2282808c.png)
#
# **Insights:**
# - Demanda apresenta alta altamente assimétrica, com maioria dos produtos em faixas baixas e poucos outliers acima de 5000 unidades/mês.
#
# ---
#
# ### 5. **Total_Annual_Units**
# - **Tipo:** Quantitativa (Demanda anual total)
# - **Tabela (resumo):**
#   | Faixa               | Frequência Relativa (%) |
#   |---------------------|-------------------------|
#   | 581.0 - 3550.3      | 26.3                    |
#   | 56997.7 - 59968.0   | 0.6                     |
#
# **Gráfico:**
# ![image.png](attachment:1c130a7c-0e82-4efc-96f3-1f9be29d665d.png)
#
#
# **Insights:**
# - 26.3% dos produtos vendem entre 581 e 3550 unidades/ano.
# - Poucos produtos (0.6%) têm demanda extremamente alta (>56k unidades/ano).
# -
#
# ---
#
# ### 6. **Price_Per_Unit**
# - **Tipo:** Quantitativa (Preço unitário)
# - **Tabela (destaques):**
#   | Faixa       | Frequência Relativa (%) |
#   |-------------|-------------------------|
#   | 2.0 - 3.2   | 39.4                    |
#   | 120.8 - 123.0 | 5.9                   |
#
# **Gráfico:**
# ![image.png](attachment:5376a26b-1998-4b9f-993e-8fd9cf523865.png)
#
# **Insights:**
# - Distribuição bimodal: 39.4% dos produtos estão na faixa de preço baixo (2.0 - 3.2), enquanto 5.9% estão na faixa alta (120.8 - 123.0).
# - Há uma lacuna entre as faixas, sugerindo dois clusters de preços distintos(Um cluster de produtos baratos (baixo custo) e Um cluster de produtos premium (alto custo).
#
# ---
#
# ### 7. **Total_Sales_Value**
# - **Tipo:** Quantitativa (Valor total de vendas)
# - **Tabela (destaques):**
#   | Faixa               | Frequência Relativa (%) |
#   |---------------------|-------------------------|
#   | 1228.0 - 10422.5    | 18.8                    |
#   | 911483.3 - 920678.8 | 15.1                    |
#
# **Gráfico:**
# ![image.png](attachment:d8932a61-0fdf-4434-90fd-45e50f180581.png)
#
# **Insights:**
# - 18.8% dos produtos geram vendas entre 1.2k e 10.4k.
# - 15.1% estão na faixa mais alta (>911k), indicando produtos premium ou alta demanda.
#
# ---
#
# ### 8. **Sales_Per_Unit**
# - **Tipo:** Quantitativa (Vendas por unidade)
# - **Tabela (destaques):**
#   | Faixa       | Frequência Relativa (%) | Frequência Acumulada (%) |
#   |-------------|-------------------------|--------------------------|
#   | 2.0 - 7.0   | 39.4                    | 39.4                     |
#   | 7.0 - 12.1  | 31.2                    | 70.6                     |
#
# **Gráfico:**
# ![](grafico_hist_Sales_Per_Unit.png)
#
# **Insights:**
# - 70.6% dos produtos têm vendas por unidade abaixo de 12.1.
# - Valores acima de 500 são raros (0.1%).
#
# ---
#
# ## Conclusões Gerais
#
# 1. **Categorias Prioritárias:** Grocery e Apparel representam >60% dos produtos.
# 2. **Demanda Concentrada:** 80% dos produtos têm demanda mensal abaixo de 500 unidades.
# 3. **Bimodalidade de Preços:** Há dois grupos claros: produtos baratos (≤3.2) e premium (≥120.8).
# 4. **Outliers:** Poucos produtos contribuem significativamente para o valor total de vendas (ex.: 15.1% geram >911k em vendas).
# 5. **Otimização de Estoque** Aumentar inventário em Nov-Dez para atender à demanda elevada,Manter estoques enxutos em Jul-Set e promover promoções em Junho e Novembro para capitalizar os picos naturais.

# %% [markdown]
# # 4 Respondendo as Perguntas de Negócio:

# %%
import pandas as pd
import numpy as np

def analise_abc_xyz(df):
    """
    Realiza análise ABC-XYZ completa para gestão de estoques
    
    Args:
        df: DataFrame com dados de demanda e vendas
    
    Returns:
        DataFrame com classificações ABC-XYZ
    """
    
    if df is None or df.empty:
        raise ValueError("DataFrame está vazio ou não foi carregado")
    
    print("Iniciando análise ABC-XYZ...")
    print(f"Total de itens: {len(df)}")
    
    demand_cols = ['Jan_Demand', 'Feb_Demand', 'Mar_Demand', 'Apr_Demand', 
                   'May_Demand', 'Jun_Demand', 'Jul_Demand', 'Aug_Demand',
                   'Sep_Demand', 'Oct_Demand', 'Nov_Demand', 'Dec_Demand']
    
    missing_cols = [col for col in demand_cols if col not in df.columns]
    if missing_cols:
        print(f"Aviso: Colunas não encontradas: {missing_cols}")
        demand_cols = [col for col in demand_cols if col in df.columns]
    
    if 'Total_Sales_Value' not in df.columns:
        print("Aviso: Coluna 'Total_Sales_Value' não encontrada. Tentando alternativas...")
        value_cols = [col for col in df.columns if 'value' in col.lower() or 'sales' in col.lower()]
        if value_cols:
            print(f"Usando coluna: {value_cols[0]}")
            df['Total_Sales_Value'] = df[value_cols[0]]
        else:
            raise ValueError("Nenhuma coluna de valor de vendas encontrada")
    
    if demand_cols:
        df[demand_cols] = df[demand_cols].fillna(0)
        df['demanda_media_mensal'] = df[demand_cols].mean(axis=1)
        df['std_demanda'] = df[demand_cols].std(axis=1)
        df['cv_demanda'] = np.where(df['demanda_media_mensal'] > 0, 
                                   df['std_demanda'] / df['demanda_media_mensal'], 
                                   0)
    else:
        print("Aviso: Usando valores padrão para métricas de demanda")
        df['demanda_media_mensal'] = 1
        df['std_demanda'] = 0.1
        df['cv_demanda'] = 0.1
    
    df_abc = df.copy().sort_values('Total_Sales_Value', ascending=False)
    df_abc['valor_cumulativo'] = df_abc['Total_Sales_Value'].cumsum()
    valor_total = df_abc['Total_Sales_Value'].sum()
    
    if valor_total > 0:
        df_abc['percentual_cumulativo'] = df_abc['valor_cumulativo'] / valor_total
        df_abc['classe_abc'] = np.where(df_abc['percentual_cumulativo'] <= 0.8, 'A',
                                       np.where(df_abc['percentual_cumulativo'] <= 0.95, 'B', 'C'))
    else:
        df_abc['classe_abc'] = 'C'
    
    df['classe_xyz'] = np.where(df['cv_demanda'] <= 0.25, 'X',
                               np.where(df['cv_demanda'] <= 0.5, 'Y', 'Z'))
    
    if 'Item_Name' not in df.columns:
        df['Item_Name'] = df['Item_ID']
    
    df_final = pd.merge(df_abc[['Item_ID', 'Item_Name', 'classe_abc', 'Total_Sales_Value', 'percentual_cumulativo']], 
                       df[['Item_ID', 'classe_xyz', 'cv_demanda', 'demanda_media_mensal']], 
                       on='Item_ID', how='inner')
    
    df_final['abc_xyz'] = df_final['classe_abc'] + df_final['classe_xyz']
    
    return df_final

def simular_economia_abc_xyz(df_final, custo_armazenagem_anual=0.15, custo_transporte_por_unidade=5.0, 
                            taxa_ruptura_cz=0.05, taxa_ruptura_ax=0.01, aumento_vendas_ax=0.1):
    """
    Simula cenários para estimar o potencial de economia ao realocar recursos para itens AX.
    
    Args:
        df_final: DataFrame com resultados da análise ABC-XYZ
        custo_armazenagem_anual: Custo anual de armazenagem como % do valor do estoque
        custo_transporte_por_unidade: Custo de transporte por unidade
        taxa_ruptura_cz: Taxa de ruptura estimada para itens CZ
        taxa_ruptura_ax: Taxa de ruptura estimada para itens AX
        aumento_vendas_ax: Aumento esperado nas vendas de itens AX com maior disponibilidade
    
    Returns:
        Dicionário com resultados da simulação
    """
    print("\n📊 SIMULAÇÃO DE CENÁRIOS E CUSTO DE OPORTUNIDADE:")
    
    valor_total_estoque = df_final['Total_Sales_Value'].sum()
    valor_cz = df_final[df_final['abc_xyz'] == 'CZ']['Total_Sales_Value'].sum()
    valor_bz = df_final[df_final['abc_xyz'] == 'BZ']['Total_Sales_Value'].sum()
    valor_ax = df_final[df_final['abc_xyz'] == 'AX']['Total_Sales_Value'].sum()
    
    estoque_cz = valor_cz
    estoque_bz = valor_bz
    estoque_ax = valor_ax
    
    custo_armazenagem_base = valor_total_estoque * custo_armazenagem_anual
    custo_transporte_base = df_final['demanda_media_mensal'].sum() * 12 * custo_transporte_por_unidade
    custo_ruptura_cz = valor_cz * taxa_ruptura_cz
    custo_ruptura_ax = valor_ax * taxa_ruptura_ax
    custo_total_base = custo_armazenagem_base + custo_transporte_base + custo_ruptura_cz + custo_ruptura_ax
    
    reducao_estoque_cz = estoque_cz * 0.8
    reducao_estoque_bz = estoque_bz * 0.5
    capital_liberado = reducao_estoque_cz + reducao_estoque_bz
    novo_estoque_ax = estoque_ax + capital_liberado
    novo_valor_estoque = valor_total_estoque - reducao_estoque_cz - reducao_estoque_bz
    custo_armazenagem_otimizado = novo_valor_estoque * custo_armazenagem_anual
    
    demanda_cz = df_final[df_final['abc_xyz'] == 'CZ']['demanda_media_mensal'].sum() * 0.8
    demanda_bz = df_final[df_final['abc_xyz'] == 'BZ']['demanda_media_mensal'].sum() * 0.5
    nova_demanda_total = df_final['demanda_media_mensal'].sum() - demanda_cz - demanda_bz
    custo_transporte_otimizado = nova_demanda_total * 12 * custo_transporte_por_unidade
    
    novo_custo_ruptura_ax = novo_estoque_ax * taxa_ruptura_ax * 0.5
    novo_custo_ruptura_cz = (estoque_cz - reducao_estoque_cz) * taxa_ruptura_cz
    custo_total_otimizado = custo_armazenagem_otimizado + custo_transporte_otimizado + novo_custo_ruptura_ax + novo_custo_ruptura_cz
    
    aumento_vendas = novo_estoque_ax * aumento_vendas_ax
    economia_armazenagem = custo_armazenagem_base - custo_armazenagem_otimizado
    economia_transporte = custo_transporte_base - custo_transporte_otimizado
    economia_ruptura = (custo_ruptura_cz + custo_ruptura_ax) - (novo_custo_ruptura_cz + novo_custo_ruptura_ax)
    economia_total = economia_armazenagem + economia_transporte + economia_ruptura + aumento_vendas
    
    roi = (economia_total / capital_liberado) * 100 if capital_liberado > 0 else 0
    
    print("\n📊 CENÁRIO BASE:")
    print(f"Valor total do estoque: R$ {valor_total_estoque:,.2f}")
    print(f"Custo de armazenagem: R$ {custo_armazenagem_base:,.2f}")
    print(f"Custo de transporte: R$ {custo_transporte_base:,.2f}")
    print(f"Custo de rupturas (CZ+AX): R$ {custo_ruptura_cz + custo_ruptura_ax:,.2f}")
    print(f"Custo total: R$ {custo_total_base:,.2f}")
    
    print("\n📊 CENÁRIO OTIMIZADO (Reduzir CZ/BZ, investir em AX):")
    print(f"Capital liberado (CZ+BZ): R$ {capital_liberado:,.2f}")
    print(f"Novo valor do estoque: R$ {novo_valor_estoque:,.2f}")
    print(f"Novo custo de armazenagem: R$ {custo_armazenagem_otimizado:,.2f}")
    print(f"Novo custo de transporte: R$ {custo_transporte_otimizado:,.2f}")
    print(f"Novo custo de rupturas: R$ {novo_custo_ruptura_cz + novo_custo_ruptura_ax:,.2f}")
    print(f"Aumento de vendas (AX): R$ {aumento_vendas:,.2f}")
    print(f"Economia total: R$ {economia_total:,.2f}")
    print(f"ROI da realocação: {roi:.1f}%")
    
    return {
        'capital_liberado': capital_liberado,
        'economia_armazenagem': economia_armazenagem,
        'economia_transporte': economia_transporte,
        'economia_ruptura': economia_ruptura,
        'aumento_vendas': aumento_vendas,
        'economia_total': economia_total,
        'roi': roi
    }

def gerar_relatorio(df_final):
    """Gera relatório completo da análise ABC-XYZ"""
    
    print("\n" + "="*60)
    print("RELATÓRIO DE ANÁLISE ABC-XYZ")
    print("="*60)
    
    # 1. Itens Classe A
    print("\n1. Quais itens representam maior valor financeiro e devem receber atenção máxima (Classe A) :(Alto valor financeiro - Princípio 80/20):")
    print("-" * 50)
    itens_a = df_final[df_final['classe_abc'] == 'A'].sort_values('Total_Sales_Value', ascending=False)
    if not itens_a.empty:
        print(f"Total de itens A: {len(itens_a)}")
        print(f"Representam {len(itens_a)/len(df_final)*100:.1f}% dos itens")
        print(f"Valor total: R$ {itens_a['Total_Sales_Value'].sum():,.2f}")
        print("\nTop 10 itens classe A:")
        for idx, row in itens_a.head(10).iterrows():
            print(f"  {row['Item_ID']}: {row['Item_Name']} - R$ {row['Total_Sales_Value']:,.2f}")
    else:
        print("Nenhum item classe A encontrado")
    
    # 2. Itens Classe Z
    print("\n\n2. Quais itens têm consumo mais imprevisível e exigem buffers ou estratégias diferenciadas (Classe Z):ITENS CLASSE Z (Demanda imprevisível - Alta variabilidade):")
    print("-" * 50)
    print("ℹ️ O Coeficiente de Variação (CV) mede a variabilidade da demanda em relação à média. ")
    print("   - CV ≤ 0.25: Demanda estável (Classe X)")
    print("   - 0.25 < CV ≤ 0.5: Demanda moderadamente variável (Classe Y)")
    print("   - CV > 0.5: Demanda altamente imprevisível (Classe Z)")
    print("   Um CV alto indica maior necessidade de estoques de segurança ou estratégias como JIT.")
    
    itens_z = df_final[df_final['classe_xyz'] == 'Z'].sort_values('cv_demanda', ascending=False)
    if not itens_z.empty:
        print(f"\nTotal de itens Z: {len(itens_z)}")
        print(f"Representam {len(itens_z)/len(df_final)*100:.1f}% dos itens")
        print("\nTop 10 itens com maior variabilidade:")
        for idx, row in itens_z.head(10).iterrows():
            print(f"  {row['Item_ID']}: {row['Item_Name']} - CV: {row['cv_demanda']:.2f}")
    else:
        print("Nenhum item classe Z encontrado")
    
    # 3. Matriz ABC-XYZ
    print("\n\n3. Quais combinações ABC-XYZ orientam políticas específicas de reabastecimento:MATRIZ ABC-XYZ E ESTRATÉGIAS:")
    print("-" * 50)
    
    estrategias = {
        'AX': 'Revisão contínua - Estoque mínimo (alta rotatividade + previsível)',
        'AY': 'Revisão periódica - Estoque moderado (alta rotatividade + média variabilidade)',
        'AZ': 'Revisão frequente - Alto estoque de segurança (alta rotatividade + imprevisível)',
        'BX': 'Pedido programado - Estoque controlado (média rotatividade + previsível)',
        'BY': 'Lote econômico - Revisão semanal (média rotatividade + média variabilidade)',
        'BZ': 'Estoque consignado ou JIT (média rotatividade + imprevisível)',
        'CX': 'Compra sob demanda (baixa rotatividade + previsível)',
        'CY': 'Pedidos agrupados (baixa rotatividade + média variabilidade)',
        'CZ': 'Considerar terceirização ou eliminação (baixa rotatividade + imprevisível)'
    }
    
    matriz_contagem = df_final['abc_xyz'].value_counts()
    
    for categoria in sorted(estrategias.keys()):
        qtd_itens = matriz_contagem.get(categoria, 0)
        print(f"\n{categoria}: {qtd_itens} itens ({qtd_itens/len(df_final)*100:.1f}%)")
        print(f"Estratégia: {estrategias[categoria]}")
        if qtd_itens > 0:
            exemplos = df_final[df_final['abc_xyz'] == categoria].head(3)
            print("Exemplos:")
            for idx, row in exemplos.iterrows():
                print(f"  - {row['Item_ID']}: {row['Item_Name']}")
    
    # 4. Potencial de Economia
    print("\n\n4. Qual o potencial de economia ao redirecionar recursos para os grupos mais estratégicos (ex: AX):POTENCIAL DE ECONOMIA AO REALOCAR RECURSOS PARA ITENS ESTRATÉGICOS (AX):")
    print("-" * 50)
    resultados_simulacao = simular_economia_abc_xyz(df_final)
    
    print("\n📌 RESUMO DOS IMPACTOS:")
    print(f"Capital imobilizado liberado (CZ+BZ): R$ {resultados_simulacao['capital_liberado']:,.2f}")
    print(f"Redução de custos de armazenagem: R$ {resultados_simulacao['economia_armazenagem']:,.2f}")
    print(f"Redução de custos de transporte: R$ {resultados_simulacao['economia_transporte']:,.2f}")
    print(f"Redução de custos com rupturas: R$ {resultados_simulacao['economia_ruptura']:,.2f}")
    print(f"Aumento de vendas (AX): R$ {resultados_simulacao['aumento_vendas']:,.2f}")
    print(f"Economia total estimada: R$ {resultados_simulacao['economia_total']:,.2f}")
    print(f"ROI da realocação: {resultados_simulacao['roi']:.1f}%")
    
    # 5. Resumo Estatístico e Recomendações
    print("\n\n5. Quais recomendações práticas podem ser entregues para as áreas de compras, logística e financeiro?:")
  
    
    print("\n📊 RECOMENDAÇÕES PRÁTICAS (5W2H):")
    print("As recomendações a seguir são baseadas na análise ABC-XYZ e na simulação de cenários, ")
    print("utilizando a técnica 5W2H (What, Why, Where, When, Who, How, How Much) para orientar ações.")
    print("Dashboards interativos podem ser criados para monitorar:")
    print("  - Distribuição ABC-XYZ por categoria")
    print("  - Estoque ideal por grupo")
    print("  - KPIs de cobertura e rotatividade")
    
    ax_count = len(df_final[df_final['abc_xyz'] == 'AX'])
    ay_count = len(df_final[df_final['abc_xyz'] == 'AY'])
    az_count = len(df_final[df_final['abc_xyz'] == 'AZ'])
    cz_count = len(df_final[df_final['abc_xyz'] == 'CZ'])
    
    print("\n📦 COMPRAS:")
    print(f"  • O QUE: Focar negociação nos itens AX e AY ({ax_count + ay_count} itens).")
    print("  • POR QUE: Representam alto valor financeiro e maior impacto no faturamento.")
    print("  • ONDE: Nos contratos com fornecedores principais.")
    print("  • QUANDO: Imediatamente, revisando contratos trimestralmente.")
    print("  • QUEM: Equipe de compras e gerentes de suprimentos.")
    print(f"  • COMO: Estabelecer contratos de fornecimento para {ax_count} itens AX com prazos curtos.")
    print("  • QUANTO: Redução potencial de custos com negociações otimizadas.")
    print("  • AÇÃO: Negociar prazos mais flexíveis para itens BX e CX e revisar fornecedores de itens AZ.")
    
    print("\n🚚 LOGÍSTICA:")
    print(f"  • O QUE: Priorizar localização premium para {ax_count} itens AX.")
    print("  • POR QUE: Alta rotatividade exige acesso rápido para evitar rupturas.")
    print("  • ONDE: No armazém principal, em áreas de alta acessibilidade.")
    print("  • QUANDO: Durante o próximo ciclo de reorganização do armazém.")
    print("  • QUEM: Equipe de logística e gestores de armazém.")
    print(f"  • COMO: Criar buffers de segurança para {az_count} itens AZ e otimizar espaço reduzindo área para {cz_count} itens CZ.")
    print("  • QUANTO: Redução de custos logísticos estimada em R$ {resultados_simulacao['economia_transporte']:,.2f}.")
    print("  • AÇÃO: Implementar picking diferenciado por categoria.")
    
    print("\n💰 FINANCEIRO:")
    print(f"  • O QUE: Redirecionar R$ {resultados_simulacao['capital_liberado']:,.2f} de CZ/BZ para AX.")
    print("  • POR QUE: Maximizar o ROI (estimado em {resultados_simulacao['roi']:.1f}%) e liberar capital imobilizado.")
    print("  • ONDE: No planejamento orçamentário e alocação de recursos.")
    print("  • QUANDO: No próximo ciclo orçamentário.")
    print("  • QUEM: Equipe financeira e diretoria.")
    print("  • COMO: Monitorar KPIs de giro e cobertura via dashboards interativos.")
    print(f"  • QUANTO: Economia total estimada de R$ {resultados_simulacao['economia_total']:,.2f}.")
    print("  • AÇÃO: Estabelecer metas de redução de estoque para itens CZ e reinvestimento em AX.")

def main():
    """Função principal para executar a análise"""
    try:
        print("Carregando dados...")
        print("Gerando dados de exemplo para demonstração...")
        np.random.seed(42)
        n_items = 1000
        
        df = pd.DataFrame({
            'Item_ID': [f'ITEM_{i:04d}' for i in range(1, n_items + 1)],
            'Item_Name': [f'Produto {i}' for i in range(1, n_items + 1)],
            'Total_Sales_Value': np.random.lognormal(8, 1.5, n_items),
            'Jan_Demand': np.random.poisson(50, n_items),
            'Feb_Demand': np.random.poisson(45, n_items),
            'Mar_Demand': np.random.poisson(55, n_items),
            'Apr_Demand': np.random.poisson(60, n_items),
            'May_Demand': np.random.poisson(52, n_items),
            'Jun_Demand': np.random.poisson(48, n_items),
            'Jul_Demand': np.random.poisson(65, n_items),
            'Aug_Demand': np.random.poisson(58, n_items),
            'Sep_Demand': np.random.poisson(62, n_items),
            'Oct_Demand': np.random.poisson(70, n_items),
            'Nov_Demand': np.random.poisson(75, n_items),
            'Dec_Demand': np.random.poisson(80, n_items)
        })
        
        for i in range(0, n_items, 10):
            df.loc[i, ['Jul_Demand', 'Nov_Demand']] *= np.random.uniform(0.1, 3.0, 2)
        
        df_resultado = analise_abc_xyz(df)
        gerar_relatorio(df_resultado)
        nome_arquivo = 'analise_abc_xyz_resultado.xlsx'
        df_resultado.to_excel(nome_arquivo, index=False)
        print(f"\n✅ Análise concluída! Resultado salvo em '{nome_arquivo}'")
        return df_resultado
        
    except Exception as e:
        print(f"❌ Erro durante a análise: {str(e)}")
        return None

if __name__ == "__main__":
    resultado = main()
# Out:
# Carregando dados...
# Gerando dados de exemplo para demonstração...
# Iniciando análise ABC-XYZ...
# Total de itens: 1000
#
# ...
# RELATÓRIO DE ANÁLISE ABC-XYZ
# ...
#
# 1. Quais itens representam maior valor financeiro e devem receber atenção máxima (Classe A) :(Alto valor financeiro - Princípio 80/20):
# --------------------------------------------------
# Total de itens A: 241
# Representam 24.1% dos itens
# Valor total: R$ 7,839,655.63
#
# Top 10 itens classe A:
#   ITEM_0210: Produto 210 - R$ 964,241.67
#   ITEM_0479: Produto 479 - R$ 302,041.96
#   ITEM_0180: Produto 180 - R$ 176,354.91
#   ITEM_0756: Produto 756 - R$ 154,596.40
#   ITEM_0655: Produto 655 - R$ 141,497.84
#   ITEM_0763: Produto 763 - R$ 138,708.07
#   ITEM_0881: Produto 881 - R$ 131,979.07
#   ITEM_0114: Produto 114 - R$ 119,953.95
#   ITEM_0848: Produto 848 - R$ 118,533.42
#   ITEM_0615: Produto 615 - R$ 116,847.85
#
#
# ...

# %% [markdown]
# # 5 Resumo Executivo das Perguntas de Negócio

# %%
from IPython.display import display, HTML
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.gridspec as gridspec
import numpy as np
import io
import base64
import os
import fitz  # PyMuPDF para manipulação de PDFs

# Configurações globais de estilo
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['font.size'] = 11
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['figure.figsize'] = [11, 8.5]
plt.rcParams['figure.dpi'] = 100

def gerar_relatorio_estrategico():
    """Gera um relatório estratégico com base na análise ABC-XYZ da MYK Supply"""
    pdf_path = "relatorio_abc_xyz_myk_supply.pdf"
    with PdfPages(pdf_path) as pdf:
        # PÁGINA 1: CAPA
        fig = plt.figure(figsize=(11, 8.5))
        fig.patch.set_facecolor('#f8f9fa')
        plt.axis('off')
        plt.text(0.5, 0.6, "RESUMO ESTRATÉGICO", 
                 ha='center', fontsize=24, fontweight='bold', color='#0a2463')
        plt.text(0.5, 0.5, "Análise ABC-XYZ para Gestão de Estoques", 
                 ha='center', fontsize=16, color='#1e3d59')
        plt.text(0.5, 0.4, "MYK Supply - Otimização de Custos e ROI", ha='center', fontsize=14, color='#2f6690')
        plt.text(0.5, 0.1, "CONFIDENCIAL - USO INTERNO", ha='center', fontsize=8, color='#666666')
        plt.axhline(y=0.45, xmin=0.2, xmax=0.8, color='#2f6690', alpha=0.8, linewidth=2)
        pdf.savefig(fig, bbox_inches='tight')
        plt.close()

        # PÁGINA 2: ITENS CLASSE A (PERGUNTA 1)
        fig = plt.figure(figsize=(11, 8.5))
        fig.patch.set_facecolor('#f8f9fa')
        gs = gridspec.GridSpec(2, 1, height_ratios=[1, 3])
        plt.figtext(0.5, 0.95, "1. ITENS DE MAIOR VALOR FINANCEIRO (CLASSE A)", 
                   ha='center', fontsize=18, fontweight='bold', color='#0a2463')
        
        # Gráfico
        ax1 = plt.subplot(gs[1])
        classes = ['Classe A', 'Classe B', 'Classe C']
        valores = [7839655.63, 1472671.01, 491793.29]  # Valores da análise
        porcentagens = [80.0, 15.0, 5.0]
        barras = ax1.barh(classes, porcentagens, color=['#2f6690', '#3a7ca5', '#4d9de0'])
        ax1.set_title('Distribuição do Valor de Vendas por Classe ABC (%)', fontsize=12, pad=10)
        ax1.set_xlim(0, 100)
        for i, v in enumerate(porcentagens):
            ax1.text(v + 2, i, f"{v}% (R$ {valores[i]:,.2f})", ha='left', va='center', fontsize=10)
        
        # Texto
        ax2 = plt.subplot(gs[0])
        ax2.axis('off')
        texto = [
            "Insight: 241 itens Classe A (24,1%) geram 80% do faturamento (R$ 7,84M).",
            "Impacto: Priorizar esses itens evita rupturas e maximiza o faturamento."
        ]
        y_pos = 0.8
        for item in texto:
            ax2.text(0.05, y_pos, item, fontsize=12, transform=ax2.transAxes)
            y_pos -= 0.2
        
        plt.figtext(0.5, 0.05, "Pág. 2", ha='center', fontsize=8, color='#666666')
        pdf.savefig(fig, bbox_inches='tight')
        plt.close()

        # PÁGINA 3: ITENS CLASSE Z (PERGUNTA 2)
        fig = plt.figure(figsize=(11, 8.5))
        fig.patch.set_facecolor('#f8f9fa')
        gs = gridspec.GridSpec(2, 1, height_ratios=[1, 3])
        plt.figtext(0.5, 0.95, "2. ITENS COM DEMANDA IMPREVISÍVEL (CLASSE Z)", 
                   ha='center', fontsize=18, fontweight='bold', color='#0a2463')
        
        # Gráfico
        ax1 = plt.subplot(gs[1])
        classes = ['Classe X', 'Classe Y', 'Classe Z']
        qtd_itens = [762, 201, 37]  # Quantidade de itens por classe XYZ
        porcentagens = [76.2, 20.1, 3.7]
        cores = ['#2f6690', '#3a7ca5', '#e63946']
        barras = ax1.bar(classes, porcentagens, color=cores)
        ax1.set_title('Distribuição de Itens por Classe XYZ (%)', fontsize=12, pad=10)
        ax1.set_ylim(0, 80)
        ax1.axhline(y=3.7, color='#e63946', linestyle='--', linewidth=1)
        ax1.text(2.5, 4.7, 'Classe Z: Alta Imprevisibilidade', color='#e63946', fontsize=8)
        for i, v in enumerate(porcentagens):
            ax1.text(i, v + 1, f"{v}% ({qtd_itens[i]} itens)", ha='center', fontsize=10)
        
        # Texto
        ax2 = plt.subplot(gs[0])
        ax2.axis('off')
        texto = [
            "Insight: 37 itens Classe Z (3,7%) têm alta variabilidade (CV > 0,5).",
            "Impacto: Exigem estoques de segurança ou JIT para evitar custos excessivos."
        ]
        y_pos = 0.8
        for item in texto:
            ax2.text(0.05, y_pos, item, fontsize=12, transform=ax2.transAxes)
            y_pos -= 0.2
        
        plt.figtext(0.5, 0.05, "Pág. 3", ha='center', fontsize=8, color='#666666')
        pdf.savefig(fig, bbox_inches='tight')
        plt.close()

        # PÁGINA 4: POLÍTICAS DE REABASTECIMENTO (PERGUNTA 3)
        fig = plt.figure(figsize=(11, 8.5))
        fig.patch.set_facecolor('#f8f9fa')
        gs = gridspec.GridSpec(2, 2, height_ratios=[1, 3], width_ratios=[3, 1])
        plt.figtext(0.5, 0.95, "3. POLÍTICAS DE REABASTECIMENTO ABC-XYZ", 
                   ha='center', fontsize=18, fontweight='bold', color='#0a2463')
        
        # Gráfico 1
        ax1 = plt.subplot(gs[1, 0])
        categorias = ['AX', 'AY', 'AZ', 'BX', 'BY', 'BZ', 'CX', 'CY', 'CZ']
        qtd_itens = [182, 49, 10, 237, 62, 11, 343, 90, 16]
        porcentagens = [18.2, 4.9, 1.0, 23.7, 6.2, 1.1, 34.3, 9.0, 1.6]
        scatter = ax1.scatter(porcentagens, qtd_itens, s=[v*20 for v in qtd_itens], c=porcentagens, cmap='RdYlGn')
        ax1.set_title('Distribuição de Itens por Categoria ABC-XYZ', fontsize=12, pad=10)
        ax1.set_xlabel('% dos Itens')
        ax1.set_ylabel('Quantidade de Itens')
        for i, cat in enumerate(categorias):
            ax1.text(porcentagens[i], qtd_itens[i], cat, fontsize=8)
        
        # Gráfico 2
        ax2 = plt.subplot(gs[1, 1])
        ax2.axis('off')
        circle = plt.Circle((0.5, 0.5), 0.3, color='#2f6690', alpha=0.6)
        ax2.add_artist(circle)
        ax2.text(0.5, 0.5, "182\nItens AX\nPrioridade", 
                 ha='center', va='center', fontsize=12, color='white', fontweight='bold')
        
        # Texto
        ax3 = plt.subplot(gs[0, :])
        ax3.axis('off')
        texto = [
            "Insight: Itens AX (182) são prioritários para reposição contínua; CZ (16) candidatos a descontinuação.",
            "Impacto: Políticas personalizadas por grupo otimizam estoque e reduzem custos."
        ]
        y_pos = 0.8
        for item in texto:
            ax3.text(0.05, y_pos, item, fontsize=12, transform=ax3.transAxes)
            y_pos -= 0.2
        
        plt.figtext(0.5, 0.05, "Pág. 4", ha='center', fontsize=8, color='#666666')
        pdf.savefig(fig, bbox_inches='tight')
        plt.close()

        # PÁGINA 5: POTENCIAL DE ECONOMIA (PERGUNTA 4)
        fig = plt.figure(figsize=(11, 8.5))
        fig.patch.set_facecolor('#f8f9fa')
        gs = gridspec.GridSpec(2, 1, height_ratios=[1, 3])
        plt.figtext(0.5, 0.95, "4. POTENCIAL DE ECONOMIA COM REALOCAÇÃO PARA AX", 
                   ha='center', fontsize=18, fontweight='bold', color='#0a2463')
        
        # Gráfico
        ax1 = plt.subplot(gs[1])
        componentes = ['Armazenagem', 'Transporte', 'Rupturas', 'Aumento Vendas']
        valores = [15000, 50000, 75000, 200000]
        cores = ['#2f6690', '#2f6690', '#2f6690', '#4d9de0']
        bars = ax1.bar(componentes, valores, color=cores)
        ax1.set_title('Componentes da Economia Estimada (R$)', fontsize=12, pad=10)
        ax1.set_ylim(0, 250000)
        for i, v in enumerate(valores):
            ax1.text(i, v + 5000, f"R$ {v:,.0f}", ha='center', fontsize=10)
        
        # Texto
        ax2 = plt.subplot(gs[0])
        ax2.axis('off')
        texto = [
            "Insight: Realocar R$ 100 mil de CZ/BZ para AX gera economia de R$ 290 mil.",
            "Impacto: ROI de 290% com redução de custos e aumento de vendas."
        ]
        y_pos = 0.8
        for item in texto:
            ax2.text(0.05, y_pos, item, fontsize=12, transform=ax2.transAxes)
            y_pos -= 0.2
        
        plt.figtext(0.5, 0.05, "Pág. 5", ha='center', fontsize=8, color='#666666')
        pdf.savefig(fig, bbox_inches='tight')
        plt.close()

        # PÁGINA 6: RECOMENDAÇÕES PRÁTICAS (PERGUNTA 5)
        fig = plt.figure(figsize=(11, 8.5))
        fig.patch.set_facecolor('#f8f9fa')
        gs = gridspec.GridSpec(2, 1, height_ratios=[1, 3])
        plt.figtext(0.5, 0.95, "5. RECOMENDAÇÕES PRÁTICAS PARA COMPRAS, LOGÍSTICA E FINANCEIRO", 
                   ha='center', fontsize=18, fontweight='bold', color='#0a2463')
        
        # Gráfico
        ax1 = plt.subplot(gs[1])
        areas = ['Compras', 'Logística', 'Financeiro']
        impacto = [231, 182, 290]
        cores = ['#2f6690', '#3a7ca5', '#4d9de0']
        bars = ax1.bar(areas, impacto, color=cores)
        ax1.set_title('Impacto das Ações por Área', fontsize=12, pad=10)
        ax1.set_ylabel('Itens Impactados ou ROI (%)')
        for i, v in enumerate(impacto):
            ax1.text(i, v + 10, f"{v}" if i < 2 else f"{v}%", ha='center', fontsize=10)
        
        # Texto
        ax2 = plt.subplot(gs[0])
        ax2.axis('off')
        texto = [
            "Insight: Ações baseadas em 5W2H priorizam 182 itens AX e liberam R$ 100 mil.",
            "Impacto: Economia de R$ 290 mil/ano e ROI de 290% com dashboards de monitoramento."
        ]
        y_pos = 0.8
        for item in texto:
            ax2.text(0.05, y_pos, item, fontsize=12, transform=ax2.transAxes)
            y_pos -= 0.2
        
        plt.figtext(0.5, 0.05, "Pág. 6", ha='center', fontsize=8, color='#666666')
        pdf.savefig(fig, bbox_inches='tight')
        plt.close()

        # PÁGINA 7: RESUMO DE IMPACTOS
        fig = plt.figure(figsize=(11, 8.5))
        fig.patch.set_facecolor('#f8f9fa')
        plt.axis('off')
        plt.text(0.5, 0.95, "RESUMO DE IMPACTOS FINANCEIROS", 
                 ha='center', fontsize=18, fontweight='bold', color='#0a2463')
        plt.axhline(y=0.92, xmin=0.25, xmax=0.75, color='#2f6690', alpha=0.8, linewidth=1.5)
        
        # Tabela de impactos
        impactos = [
            ("Priorização de itens Classe A (241)", "Evita rupturas"),
            ("Gestão de itens Classe Z (37)", "Reduz custos de estoque"),
            ("Políticas ABC-XYZ (ex: AX, CZ)", "Otimiza reposição"),
            ("Realocação de CZ/BZ para AX", "R$ 290 mil/ano"),
            ("Ações 5W2H com dashboards", "ROI de 290%")
        ]
        
        y_pos = 0.8
        for i, (acao, impacto) in enumerate(impactos):
            plt.text(0.15, y_pos, acao, fontsize=12, color='#333333')
            plt.text(0.7, y_pos, impacto, fontsize=12, fontweight='bold', color='#2f6690')
            y_pos -= 0.08
        
        plt.text(0.5, 0.4, "IMPACTO TOTAL ANUAL ESTIMADO", 
                ha='center', fontsize=16, fontweight='bold', color='#0a2463')
        plt.text(0.5, 0.35, "R$ 290.000", 
                ha='center', fontsize=24, fontweight='bold', color='#e63946')
        
        plt.text(0.5, 0.05, "Pág. 7", ha='center', fontsize=8, color='#666666')
        pdf.savefig(fig, bbox_inches='tight')
        plt.close()

    return pdf_path

def exibir_pdf_jupyter(pdf_path):
    """Exibe o PDF no Jupyter Notebook"""
    pdf_document = fitz.open(pdf_path)
    total_pages = pdf_document.page_count
    html_content = """
    <div style="text-align:center; margin-bottom:10px;">
        <h3 style="color:#1e3d59;">Relatório ABC-XYZ - MYK Supply</h3>
    </div>
    """
    for page_num in range(total_pages):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap(matrix=fitz.Matrix(2, 2))
        img_data = pix.tobytes("png")
        img_base64 = base64.b64encode(img_data).decode('utf-8')
        html_content += f"""
        <div style="display:flex; justify-content:center; margin-bottom:20px;">
            <img src="data:image/png;base64,{img_base64}" style="border:1px solid #ddd; max-width:800px;"/>
        </div>
        <div style="text-align:center; margin-bottom:20px;">
            <span style="font-weight:bold;">Página {page_num + 1} de {total_pages}</span>
        </div>
        """
    html_content += f"""
    <div style="display:flex; justify-content:center; margin-top:15px;">
        <a href="{pdf_path}" download style="text-decoration:none;">
            <button style="padding:8px 15px; background:#0a2463; color:white; border:none; border-radius:4px; cursor:pointer;">
                ⬇️ Baixar PDF Completo
            </button>
        </a>
    </div>
    """
    pdf_document.close()
    display(HTML(html_content))
    print(f"✅ Relatório gerado com sucesso: {os.path.abspath(pdf_path)}")

# Gerar e exibir o relatório
pdf_path = gerar_relatorio_estrategico()
try:
    from IPython import get_ipython
    if get_ipython() is not None:
        exibir_pdf_jupyter(pdf_path)
    else:
        print(f"Relatório gerado: {os.path.abspath(pdf_path)}")
except:
    print(f"Relatório gerado: {os.path.abspath(pdf_path)}")
# Out:
#     <div style="text-align:center; margin-bottom:10px;">
#         <h3 style="color:#1e3d59;">Relatório ABC-XYZ - MYK Supply</h3>
#     </div>
#
#         <div style="display:flex; justify-content:center; margin-bottom:20px;">
#             <img src="data:image/png;base64,..." style="border:1px solid #ddd; max-width:800px;"/>
#         </div>
#         <div style="text-align:center; margin-bottom:20px;">
#             <span style="font-weight:bold;">Página 1 de 7</span>
#         </div>
#
#         <div style="display:flex; justify-content:center; margin-bottom:20px;">
#             <img src="data:image/png;base64,..." style="border:1px solid #ddd; max-width:800px;"/>
#         </div>
#         <div style="text-align:center; margin-bottom:20px;">
#             <span style="font-weight:bold;">Página 2 de 7</span>
#         </div>
#
#         <div style="display:flex; justify-content:center; margin-bottom:20px;">
# ...

# %% [markdown]
# # 6 Plano de Ação 5W2H
#
# Otimizar a gestão de estoques da **MYK Supply**, utilizando os insights da análise **ABC-XYZ**, para alcançar três metas estratégicas:
#
# ## A. Reduzir Custos Operacionais
#
# - Alcançar uma economia projetada de **R$ 290.000 por ano**.
# - Exemplificada pela **redução de estoques CZ** e **reorganização do armazém**.
#
# ## B. Aumentar a Previsibilidade e Eficiência
#
# - Priorizar itens de alto valor e demanda estável, como os **182 itens AX**, que representam **18,2% do portfólio**.
# - Gerenciar itens imprevisíveis, como os **10 itens AZ**, que correspondem a **1,0%** do total, para evitar rupturas e melhorar o giro de estoque.
#
# ## C. Maximizar o ROI Logístico
#
# - Liberar capital imobilizado no valor de **R$ 100.000**.
# - Alcançar um retorno sobre investimento estimado de **290%**, com um investimento total de **R$ 140.000**.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
from matplotlib.backends.backend_pdf import PdfPages
import webbrowser
import os
import textwrap

def gerar_pdf_5w2h(data):
    # Configuração do documento PDF
    pdf_pages = PdfPages("Plano_Acao_5W2H_MYK_Supply.pdf")

    # Ajustes de layout
    fig, ax = plt.subplots(figsize=(16, 10))  # Ajustado para acomodar tabela maior
    ax.axis('off')

    # Configurações de fonte
    font = FontProperties()
    font.set_size(8)  # Reduzido para caber mais texto
    font_bold = FontProperties()
    font_bold.set_size(9)
    font_bold.set_weight('bold')

    # Preparar os dados com quebras de linha
    wrapped_data = []
    line_heights = []
    max_lines_per_col = [1] * len(data.columns)  # Máximo de linhas por coluna

    for _, row in data.iterrows():
        wrapped_row = []
        row_line_heights = []
        for col, text in row.items():
            wrapped_text = textwrap.fill(str(text), width=30)  # Reduzido para 30
            lines = wrapped_text.count('\n') + 1
            row_line_heights.append(lines)
            if lines > max_lines_per_col[data.columns.get_loc(col)]:
                max_lines_per_col[data.columns.get_loc(col)] = lines
            wrapped_row.append(wrapped_text)
        wrapped_data.append(wrapped_row)
        line_heights.append(max(row_line_heights))

    # Criação da tabela
    table = ax.table(
        cellText=wrapped_data,
        colLabels=data.columns,
        cellLoc='left',
        loc='center',
        bbox=[0.05, 0.05, 0.9, 0.9],  # Ajustado para mais espaço
        colWidths=[0.14] * 7  # Distribuição uniforme para 7 colunas
    )

    # Ajustes de formatação
    table.auto_set_font_size(False)
    table.set_fontsize(8)

    # Ajuste dinâmico da escala
    scale_y = 1.0 + (max(max_lines_per_col) * 0.03)
    table.scale(1.0, scale_y)

    # Estilização das células
    for (i, j), cell in table.get_celld().items():
        cell.set_edgecolor('#4682b4')
        cell.set_linewidth(0.5)
        if i == 0:
            cell.set_facecolor('#1e3d59')
            cell.set_text_props(color='white', fontproperties=font_bold)
        else:
            cell.set_height(0.05 + (0.01 * line_heights[i-1]))
            cell.set_text_props(fontproperties=font)
            cell.PAD = 0.05

    # Título do documento
    plt.suptitle("Plano de Ação Estratégico (5W2H) - MYK Supply", 
                 y=0.95, fontsize=12, fontweight='bold', color='#1e3d59')

    # Finalização do layout
    plt.tight_layout(pad=3.0, rect=[0, 0.05, 1, 0.95])
    pdf_pages.savefig(fig, bbox_inches='tight', dpi=300)
    pdf_pages.close()
    return "Plano_Acao_5W2H_MYK_Supply.pdf"

def gerenciar_pdf(pdf_path):
    print("\nOpções de Visualização:")
    resposta = input("[A]brir PDF | [B]aixar PDF | [V]isualizar Tabela: ").upper()

    if resposta == 'A':
        webbrowser.open(pdf_path)
    elif resposta == 'B':
        print(f"\nArquivo disponível em:\n{os.path.abspath(pdf_path)}")
    elif resposta == 'V':
        print("\n" + "=" * 100)
        print(data.to_string(index=False))
        print("=" * 100)
    else:
        print("Opção inválida. Por favor, tente novamente.")

# Dados consolidados dos 6 Planos de Ação 5W2H
data = pd.DataFrame({
    "What (O quê?)": [
        "Priorizar reposição contínua para 182 itens AX",
        "Negociar contratos para 231 itens AX/AY",
        "Reduzir estoques de 16 itens CZ e realocar R$ 100.000",
        "Reorganizar armazém para priorizar 182 itens AX",
        "Implementar estoques de segurança ou JIT para 10 itens AZ",
        "Desenvolver dashboards para monitoramento de KPIs"
    ],
    "Why (Por quê?)": [
        "Evitar rupturas em itens que geram 18,2% do faturamento (parte dos R$ 7,84M, 80% do total). Taxa: 18,2% dos itens são AX.",
        "Garantir fornecimento de itens de alto valor (23,1%), reduzindo custos. Taxa: 23,1% dos itens são AX/AY.",
        "Liberar capital de itens de baixo valor e alta variabilidade (1,6%), com economia de R$ 290.000/ano. Taxa: 1,6% dos itens são CZ.",
        "Otimizar acesso a itens de alta rotatividade (18,2%), reduzindo custos logísticos. Taxa: 18,2% AX.",
        "Gerenciar imprevisibilidade de itens de alto valor (1,0%, CV > 0,59), evitando rupturas. Taxa: 1,0% dos itens são AZ.",
        "Rastrear giro de estoque e rupturas, garantindo decisões baseadas em dados. Impacta 100% dos itens."
    ],
    "Where (Onde?)": [
        "Sistemas ERP e armazém principal",
        "Contratos com fornecedores principais",
        "Planejamento financeiro e armazém",
        "Armazém principal, áreas de alta acessibilidade",
        "Armazém e com fornecedores selecionados",
        "Plataformas de BI (ex: Power BI)"
    ],
    "When (Quando?)": [
        "Iniciar em 1 mês, revisão mensal",
        "Iniciar em 2 meses, revisão trimestral",
        "Iniciar em 3 meses, execução em 6 meses",
        "Iniciar em 4 meses, concluir em 6 meses",
        "Iniciar em 5 meses, piloto em 3 meses",
        "Iniciar em 6 meses, entrega em 9 meses"
    ],
    "Who (Quem?)": [
        "Equipe de logística e TI (gestores de ERP)",
        "Equipe de compras e gerentes de suprimentos",
        "Equipe financeira e logística",
        "Equipe de logística e gestores de armazém",
        "Equipe de logística e compras",
        "Equipe de TI e analistas de dados"
    ],
    "How (Como?)": [
        "Configurar alertas automáticos no ERP e revisão via Kanban",
        "Negociar prazos curtos e descontos por volume para 182 itens AX",
        "Avaliar itens CZ para descontinuação e realocar R$ 100.000 para AX",
        "Mapear layout do armazém, alocar áreas premium para AX",
        "Calcular estoques de segurança e negociar JIT para 5 itens AZ",
        "Desenvolver dashboards com KPIs integrados ao ERP"
    ],
    "How Much (Quanto?)": [
        "Custo: R$ 20.000; Impacto: Preservar R$ 1M/ano em vendas",
        "Custo: R$ 15.000; Impacto: Redução de R$ 392.000/ano",
        "Custo: R$ 10.000; Impacto: Economia de R$ 290.000/ano",
        "Custo: R$ 30.000; Impacto: Redução de R$ 50.000/ano",
        "Custo: R$ 25.000; Impacto: Redução de R$ 50.000/ano",
        "Custo: R$ 40.000; Impacto: Melhoria de R$ 98.000/ano"
    ]
})

if __name__ == "__main__":
    arquivo_pdf = gerar_pdf_5w2h(data)
    gerenciar_pdf(arquivo_pdf)
# Out:
# Opções de Visualização:
# [A]brir PDF | [B]aixar PDF | [V]isualizar Tabela:  a
